# %% [markdown]
# <a href="https://colab.research.google.com/github/KaterynaRovinska/Studies/blob/main/Variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate

from prettytable import PrettyTable
# Specify the Column Names
myTable = PrettyTable(["Observation", "Gender", "Income (€/year)", "Tenure (years)"])
 
# Add rows
myTable.add_row(["1", "Female", 17525, 4])
myTable.add_row(["2", "Female", 18240, 5])
myTable.add_row(["3", "Female", 10250, 4])
myTable.add_row(["4", "Male", 18320, 7])
myTable.add_row(["5", "Male", 17540, 3])
myTable.add_row(["6", "Female", 22500, 5])
myTable.add_row(["7", "Male", 27320, 6])
myTable.add_row(["8", "Female", 19240, 5])
myTable.add_row(["9", "Female", 14750, 4])
myTable.add_row(["10", "Male", 19790, 3])
myTable.add_row(["11", "Male", 21430, 4])

print(myTable)

#Descriptive Values
#Find the mean, median and mode

import pandas as pd 
# Create pandas DataFrame
data = pd.DataFrame({'Income':[17525, 18240, 10250, 18320, 17540, 22500, 27320, 19240, 14750, 19790, 21430],
                     'Tenure':[4,5,4,7,3,5,6,5,4,3,4],
                     'Gender':['Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male']})

# Print pandas DataFrame
print(data)

c = "---------------------------------------------------------"
print(c)
a='Mean Income'
print (a)
# Get mean of one column
print(data['Income'].mean())

c = "---------------------------------------------------------"
print(c)

b='Mean Income by Gender'
print (b)
# Get mean by gender
print(data.groupby('Gender').mean()) 
c = "---------------------------------------------------------"
print(c)

d='Median Income'
print (d)
# Get median of one column
print(data['Income'].median()) 
c = "---------------------------------------------------------"
print(c)

e='Median Income by gender'
print (e)
# Get median by gender
print(data.groupby('Gender').median())
c = "---------------------------------------------------------"
print(c)

f='Mode of income'
print (f)
# Get mode of Income - (mode of a set of data values is the value that appears most often - *there are no repeating values for income in a trable*)
print(data['Income'].mode())
c = "---------------------------------------------------------"
print(c)

g='Mode of Tenure'
print (g)
# Get mode of one column Tenure 
print(data['Tenure'].mode())
c = "---------------------------------------------------------"
print(c)

h='Standard deviation for Income'
print (h)
# Find standard deviation for Income
print(data['Income'].std()) 
c = "---------------------------------------------------------"
print(c)

i='IQR for Income'
print (i)

#Define IQR
import numpy as np

#define array of data
data = np.array([17525, 18240, 10250, 18320, 17540, 22500, 27320, 19240, 14750, 19790, 21430])

#calculate interquartile range 
q3, q1 = np.percentile(data, [75 ,25])
iqr = q3 - q1

#display interquartile range 
print('The Interquartile Range for the data is:',iqr)

#Calculating Skewness
c = "---------------------------------------------------------"
print(c)

j='Skewness for Income'
print (j)
# Importing scipy
import scipy
# Importing library
from scipy.stats import skew
# Creating a dataset
dataset = [17525, 18240, 10250, 18320, 17540, 22500, 27320, 19240, 14750, 19790, 21430]
# Calculate the skewness
print(skew(dataset, axis=0, bias=True))

#Calculating Kurtosis
c = "---------------------------------------------------------"
print(c)

k='Kurtosis for Income'
print (k)
# Importing library
from scipy.stats import kurtosis
# Creating a dataset
dataset = [17525, 18240, 10250, 18320, 17540, 22500, 27320, 19240, 14750, 19790, 21430]
# Calculate the kurtosis
print(kurtosis(dataset, axis=0, bias=True))


c = "---------------------------------------------------------"
print(c)

l='Histogram'
print (l)
import matplotlib.pyplot as plt

x = [17525, 18240, 10250, 18320, 17540, 22500, 27320, 19240, 14750, 19790, 21430],
plt.hist(x, bins=9)
plt.show()

m='Boxplot'
print (m)

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')
df = pd.DataFrame([17525, 18240, 10250, 18320, 17540, 22500, 27320, 19240, 14750, 19790, 21430])
plt.figure(figsize=(6,4))
sns.boxplot(data)
plt.show()
# Out:
# +-------------+--------+-----------------+----------------+
# | Observation | Gender | Income (€/year) | Tenure (years) |
# +-------------+--------+-----------------+----------------+
# |      1      | Female |      17525      |       4        |
# |      2      | Female |      18240      |       5        |
# |      3      | Female |      10250      |       4        |
# |      4      |  Male  |      18320      |       7        |
# |      5      |  Male  |      17540      |       3        |
# |      6      | Female |      22500      |       5        |
# |      7      |  Male  |      27320      |       6        |
# |      8      | Female |      19240      |       5        |
# |      9      | Female |      14750      |       4        |
# |      10     |  Male  |      19790      |       3        |
# |      11     |  Male  |      21430      |       4        |
# +-------------+--------+-----------------+----------------+
#     Income  Tenure  Gender
# 0    17525       4  Female
# 1    18240       5  Female
# 2    10250       4  Female
# 3    18320       7    Male
# 4    17540       3    Male
# 5    22500       5  Female
# 6    27320       6    Male
# 7    19240       5  Female
# 8    14750       4  Female
# 9    19790       3    Male
# 10   21430       4    Male
# ---------------------------------------------------------
# Mean Income
# 18809.545454545456
# ---------------------------------------------------------
# Mean Income by Gender
#               Income  Tenure
# Gender
# Female  17084.166667     4.5
# Male    20880.000000     4.6
# ---------------------------------------------------------
# Median Income
# 18320.0
# ---------------------------------------------------------
# Median Income by gender
#          Income  Tenure
# Gender
# Female  17882.5     4.5
# Male    19790.0     4.0
# ---------------------------------------------------------
# Mode of income
# 0     10250
# 1     14750
# 2     17525
# 3     17540
# 4     18240
# 5     18320
# 6     19240
# 7     19790
# 8     21430
# 9     22500
# 10    27320
# dtype: int64
# ---------------------------------------------------------
# Mode of Tenure
# 0    4
# dtype: int64
# ---------------------------------------------------------
# Standard deviation for Income
# 4331.653526394658
# ---------------------------------------------------------
# IQR for Income
# The Interquartile Range for the data is: 3077.5
# ---------------------------------------------------------
# Skewness for Income
# -0.016541705154308778
# ---------------------------------------------------------
# Kurtosis for Income
# 0.47577937228279454
# ---------------------------------------------------------
# Histogram
# Boxplot
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
